# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-04aea51c-77fb-4ac5-ab2b-ae5460748a22" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04aea51c-77fb-4ac5-ab2b-ae5460748a22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c dogs-vs-cats
# !unzip -q dogs-vs-cats.zip
# !unzip -q train.zip
# Out:
# ...
# 100% 812M/812M [00:09<00:00, 90.6MB/s]

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

dataset_path = "/content/train"

# %%
# --- Color Channel Analysis ---
img = cv2.imread(image_paths[1]) # Get another image
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Split channels
red_channel = img[:, :, 0]
green_channel = img[:, :, 1]
blue_channel = img[:, :, 2]

# %%
# EDA Visualization: Channel Histograms
plt.figure(figsize=(10, 4))

# %%
plt.hist(red_channel.ravel(), bins=50, color='red', alpha=0.5, label='Red')
plt.hist(green_channel.ravel(), bins=50, color='green', alpha=0.5, label='Green')
plt.hist(blue_channel.ravel(), bins=50, color='blue', alpha=0.5, label='Blue')
# Out:
# (array([2.218e+03, 1.247e+03, 2.356e+03, 2.636e+03, 3.514e+03, 6.150e+03,
#         6.068e+03, 9.864e+03, 8.240e+03, 7.969e+03, 9.148e+03, 5.402e+03,
#         4.270e+03, 4.695e+03, 3.218e+03, 4.029e+03, 3.030e+03, 3.184e+03,
#         4.714e+03, 3.815e+03, 4.242e+03, 5.776e+03, 4.053e+03, 5.339e+03,
#         3.988e+03, 4.023e+03, 5.499e+03, 4.205e+03, 5.696e+03, 4.138e+03,
#         4.239e+03, 5.682e+03, 4.533e+03, 4.997e+03, 6.700e+03, 4.869e+03,
#         5.616e+03, 2.922e+03, 2.035e+03, 1.454e+03, 5.280e+02, 3.300e+02,
#         2.050e+02, 9.200e+01, 9.300e+01, 4.700e+01, 2.500e+01, 2.000e+01,
#         8.000e+00, 4.000e+00]),
#  array([  0.  ,   3.38,   6.76,  10.14,  13.52,  16.9 ,  20.28,  23.66,
#          27.04,  30.42,  33.8 ,  37.18,  40.56,  43.94,  47.32,  50.7 ,
#          54.08,  57.46,  60.84,  64.22,  67.6 ,  70.98,  74.36,  77.74,
#          81.12,  84.5 ,  87.88,  91.26,  94.64,  98.02, 101.4 , 104.78,
# ...

# %%
plt.title('RGB Channel Pixel Distribution')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1933/921616731.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

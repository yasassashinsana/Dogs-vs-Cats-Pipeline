# %%
from google.colab import files
files.upload()

# !mkdir -p ~/.kaggle
# !cp "kaggle.json" ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c dogs-vs-cats
# !unzip -q dogs-vs-cats.zip
# !unzip -q train.zip

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

dataset_path = "/content/train" # Unzip  dataset  path

# Get all image paths and labels
image_paths = [os.path.join(dataset_path, fname) for fname in os.listdir(dataset_path) if fname.endswith('.jpg')]
labels = [1 if 'dog' in os.path.basename(path) else 0 for path in image_paths]

# ---  Image Resizing & Dimensionality Standardization ---
#IT number : IT25103028

IMG_SIZE = 128
X_resized = []
y_labels = [] # Part subset  labels

# EDA: before the Resize  images view  dimensions  (for 100)
widths, heights = [], []
for img_path in image_paths[:100]:
    img = cv2.imread(img_path)
    if img is not None:
        heights.append(img.shape[0])
        widths.append(img.shape[1])

plt.scatter(widths, heights, color='purple', alpha=0.5)
plt.title('Original Image Dimensions (Before Resizing)')
plt.xlabel('Width')
plt.ylabel('Height')
plt.show()

print("Resizing images... (Processing 2000 images for memory efficiency)")

#   resize images 2000  for remove RAM crash
for i in range(2000):
    img = cv2.imread(image_paths[i])
    if img is not None:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # Change BGR to RGB
        resized_img = cv2.resize(img, (IMG_SIZE, IMG_SIZE)) # Convert to 128x128
        X_resized.append(resized_img)
        y_labels.append(labels[i])

# List convert  Numpy Array  (for ML Models )
X_resized = np.array(X_resized)
y_labels = np.array(y_labels)
print(f"Resized Data Shape: {X_resized.shape}")

# Resize image display
plt.imshow(X_resized[0])
plt.title(f"Standardized Image ({IMG_SIZE}x{IMG_SIZE})")
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-5af549bb-7b89-451f-897e-d4860722b928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5af549bb-7b89-451f-897e-d4860722b928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
